# %% [markdown]
# <a href="https://colab.research.google.com/github/tyagisidd2411/DSBCS351/blob/main/Siddhanttyagi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def removeElement(self, nums, val):
        k = 0

        for num in nums:
            if num != val:
                nums[k] = num
                k += 1

# %%
    def buildArray(self, nums):
        ans = []

        for i in range(len(nums)):
            ans.append(nums[nums[i]])

        return ans

# %%
def search(self, nums, target):
        left = 0
        right = len(nums) - 1

        while left <= right:
            mid = (left + right) // 2

            if nums[mid] == target:
                return mid
            elif nums[mid] < target:
                left = mid + 1
            else:
                right = mid - 1

        return -1

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def traverse(head):
    current = head

    while current:
        print(current.data, end=" ")
        current = current.next

# %%
#Insertion at Beginning
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def insert_at_beginning(head, data):
    new_node = Node(data)
    new_node.next = head
    head = new_node
    return head


def display(head):
    current = head

    while current:
        print(current.data, end=" -> ")
        current = current.next

    print("None")


# Initially empty
head = None

head = insert_at_beginning(head, 30)
head = insert_at_beginning(head, 20)
head = insert_at_beginning(head, 10)

display(head)
# Out:
# 10 -> 20 -> 30 -> None

# %%
#Insertion at End
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def insert_at_end(head, data):
    new_node = Node(data)

    # If linked list is empty
    if head is None:
        return new_node

    current = head

    # Go to the last node
    while current.next is not None:
        current = current.next

    # Add new node at the end
    current.next = new_node

    return head


def display(head):
    current = head

    while current:
        print(current.data, end=" -> ")
        current = current.next

    print("None")


# Create linked list
head = None

head = insert_at_end(head, 10)
head = insert_at_end(head, 20)
head = insert_at_end(head, 30)
head = insert_at_end(head, 40)

display(head)
# Out:
# 10 -> 20 -> 30 -> 40 -> None

# %%
#Insertion at Kth Position
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def insert_at_kth(head, data, k):
    new_node = Node(data)

    # Insert at beginning
    if k == 0:
        new_node.next = head
        return new_node

    current = head

    # Move to node just before position k
    for i in range(k - 1):
        if current is None:
            return head
        current = current.next

    # Invalid position
    if current is None:
        return head

    new_node.next = current.next
    current.next = new_node

    return head


def display(head):
    current = head

    while current:
        print(current.data, end=" -> ")
        current = current.next

    print("None")


# Create linked list
head = Node(10)
head.next = Node(20)
head.next.next = Node(30)
head.next.next.next = Node(40)

# Insert 25 at position 2
head = insert_at_kth(head, 25, 2)

display(head)
# Out:
# 10 -> 20 -> 25 -> 30 -> 40 -> None
